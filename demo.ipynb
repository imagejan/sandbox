# %%
#@ IOService io

println io
# Out:
# org.scijava.io.DefaultIOService [priority = 0.0]
# No Outputs

# %%
img = io.open("http://2015.igem.org/wiki/images/a/a8/Focusing.gif")
# Out:
# [INFO] Verifying GIF format
# [INFO] Reading dimensions
# [INFO] Reading data blocks

# %%
img.numDimensions()
# Out:
# 4

# %%
dims = new long[img.numDimensions()]
img.dimensions(dims)

println dims
# Out:
# [800, 600, 3, 50]
# No Outputs

# %%
#@ ImageJ ij

// Define some handy shorthands!
import net.imglib2.RandomAccessibleInterval
tile = { images ->
  int[] gridLayout = images[0] in List ?
    [images[0].size, images.size] : // 2D images list
    [images.size] // 1D images list
  RandomAccessibleInterval[] rais = images.flatten()
  ij.notebook().mosaic(gridLayout, rais)
}
# Out:
# Script13&#8203;$&#8203;_run&#8203;_closure1&#8203;@7eeaad5

# %%
tile([img])
